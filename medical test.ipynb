# %% [markdown]
# # Data Analysis of Medical data
# # Introduction
#
# The notebook is based on the data from Kaggao, and the direct URL to the dataset https://www.kaggle.com/datasets/sukhmandeepsinghbrar/heart-attack-datasetet. The dataset consists of 100 samples with Nine attributes: gender, hemoglobin,
#
# Objective:
# * Find the relation between Blood sugar and Age

# %%
#importing numpy pandas mathplotand other methods
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#first read the data file
df=pd.read_csv('Medicaldataset.csv')

# %%
# quick look to dataset
df.head(100)
# Out:
#     Age  Gender  Heart rate  Systolic blood pressure  \
# 0    63       1          66                      160
# 1    20       1          94                       98
# 2    56       1          64                      160
# 3    66       1          70                      120
# 4    54       1          64                      112
# ..  ...     ...         ...                      ...
# 95   66       1          60                      129
# 96   40       1          60                       97
# 97   19       0          62                      114
# 98   58       1          75                      116
# 99   77       1          73                      115
#
#     Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 0                         83        160.0    1.80     0.012  negative
# 1                         46        296.0    6.75     1.060  positive
# 2                         77        270.0    1.99     0.003  negative
# ...

# %%
#Print summary statistics
df.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.193328     0.659591    78.336619               127.170584
# std      13.638173     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %% [markdown]
#
# * Age has a standard deviation of 13.63.
#
# * The age  data range from a minimum of 14 to a maximum of 103, exhibiting considerable variability around the mean.
#
# * This suggests a diverse distribution with notable dispersion, spanning a broad range of values.

# %%
#the complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %% [markdown]
# <!-- -In heare the total float value are 64.
#
# -the intiger value are 5.
#
# -the object of given data are 1.
#
# -total columns are 9 and index are 1319.
#
# -the data are need to 92.9kb storage.
#  -->
# * The dataset contains 1319 rows and 9 columns, with an index assigned to each row.
#
# * It encompasses various types of data, including integers, objects, and floats.
#
# * The total float values amount to 64, while there are 5 integer values and 1 object.
#
# * Storing this dataset requires approximately 92.9 kilobytes of storage.

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())

# Replace the ' 's with NaN
df = df.replace(" ",np.NaN)


# Impute the missing values with mean imputation
# df = df.fillna(df.mean())

# Count the number of NaNs in the dataset to verify
print(df.isnull().values.sum())
# Out:
# 0
# 0

# %% [markdown]
# * All data within this dataset are complete, with no null values present.

# %%
# seaborn 
sns.distplot(df['Age'],hist=True,kde=True,
            bins=12, color='blue',
            hist_kws={'edgecolor':'black'})
# ADD labels
plt.title('Age count')
plt.xlabel('Age')

plt.ylabel('count')
# Out:
# C:\Users\D E L L\AppData\Local\Temp\ipykernel_14332\2172544921.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],hist=True,kde=True,
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'count')

# %%
sns.histplot(df['Age'],bins=15)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# * Within the demographic range of 20 to 40 years old, there are a total of 55 individuals.
#
# * This data provides a clear insight into the age distribution of the population.
# * Remarkably, the age group between 50 and 60 years old stands out with a significant population of over 200
# individuals according to the graph.
#
# * As individuals age, there appears to be a decline in population numbers, indicating a natural decrease in demographics.
#
# * Additionally, it's noteworthy that the population of children is notably lower compared to the young adult demographic.
#
# * Overall, this data underscores the prominence of young adults within the population, suggesting a demographic trend favoring youth."

# %%
sns.scatterplot(x=df['Blood sugar'],y=df['Age'])
# Out:
# <Axes: xlabel='Blood sugar', ylabel='Age'>

# %% [markdown]
# * Individuals aged 60 to 80 show a higher survival rate with regards to blood sugar levels.
#
# *
# Children aged 20 to 40 years also have a significant likelihood of encountering blood sugar issues
#
# * Young individuals under the age of 20 demonstrate a diminished likelihood of experiencing blood sugar complications.
# .

# %%
sns.lineplot(x=df['Age'],y=df['Blood sugar'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Blood sugar'>

# %% [markdown]
# * individuals aged 90 to 100 are advised to undergo blood sugar monitoring.
#
# * Blood sugar tends to decrease with age from 20 years until reaching over 80 years.
#
# * There is a higher probability of blood sugar issues among individuals below 20 years of age and those above 80 years of age.

# %%
sns.boxplot(y='Age',data=df,x='Gender')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %% [markdown]
# * male denoted by 1 and femal are 0.
#
# * Females aged between 50 to 70 are more number of female this dataset.
#
# * Male aged between 47 to 65 are more  number of male  in this dataset
#
# * There are records of both males and females under the age of 20.
#
# *
# Individuals aged 100 or above, both male and female, are present in the datase.
#
# * The number of females in the dataset surpasses that of males.
#
#
#  es.

# %%
df_numeric=df.apply(pd.to_numeric,errors='coerce')

# %%
#this is heat map pearson correlation matrix
corrmat = df_numeric.corr(numeric_only=True)
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=0.8, square=True);
plt.title('Pearson Correlation Matrix Heatmap',fontsize=16)
plt.show()
df_coy = df.copy()

# %% [markdown]
# * The heat map displays a weak negative correlation between age and blood sugar levels.
#
# * Overall, the majority of the data points on the heatmap indicate blood sugar rates below 0.
#
# * The distribution suggests that as age increases, there tends to be a slight decrease in blood sugar levels, although the correlation is not strong.
#
# * There may be some variability in blood sugar levels across different age groups, but the general trend indicates lower blood sugar levels across the board.

# %%
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features', size = 15)
colormap = sns.diverging_palette(10, 220, as_cmap = True)
sns.heatmap(df_numeric.corr(),
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':12 })
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# <!-- In above correlation matrix, we printed the number also so it will be easy for us to see which are highly corelated Value close to 1.00 is highly corelated

# As per our objective,we see that "age" and "absences" have value 0.15 which is below 0.25 and we can say that they are not so correlated -->

# %% [markdown]
# # Finding

# %% [markdown]
# * A standard deviation of 13.63.
# * The data range from a minimum of 14 to a maximum of 103, exhibiting considerable variability around the mean.
# * This suggests a diverse distribution with notable dispersion, spanning a broad range of values.
# * The dataset contains 1319 rows and 9 columns, with an index assigned to each row.
# * It encompasses various types of data, including integers, objects, and floats.
# * The total float values amount to 64, while there are 5 integer values and 1 object.
# * Storing this dataset requires approximately 92.9 kilobytes of storage.
# * all data are full and no more is null in this data
# * Within the demographic range of 20 to 40 years old, there are a total of 55 individuals.
# * This data provides a clear insight into the age distribution of the population.
# * Remarkably, the age group between 50 and 60 years old stands out with a significant population of over 200 individuals according to the graph.
# * As individuals age, there appears to be a decline in population numbers, indicating a natural decrease in demographics.
# * Additionally, it's noteworthy that the population of children is notably lower compared to the young adult demographic.
# * Overall, this data underscores the prominence of young adults within the population, suggesting a demographic trend favoring youth."
# * individuals aged 90 to 100 are advised to undergo blood sugar monitoring.
# * Blood sugar tends to decrease with age from 20 years until reaching over 80 years.
# * There is a higher probability of blood sugar issues among individuals below 20 years of age and those above 80 years of age.
# * male denoted by 1 and femal are 0.
# * Females aged between 50 to 70 are more number of female this dataset.
# * Male aged between 47 to 65 are more number of male in this dataset
# * There are records of both males and females under the age of 20.
# * Individuals aged 100 or above, both male and female, are present in the datase.
# * The number of females in the dataset surpasses that of males.
# * The heat map displays a weak negative correlation between age and blood sugar levels.
#
# * verall, the majority of the data points on the heatmap indicate blood sugar rates below .
#
# * The distribution suggests that as age increases, there tends to be a slight decrease in blood sugar levels, although the correlation is not strng<!-- .
#
# * There may be some variability in blood sugar levels across different age groups, but the general trend indicates lower blood sugar levels across the  -->o
# <!-- Unlocking Insights from Demographic and Health Data
#
# In the vast sea of data spanning 1319 rows and 9 columns, a narrative of our population's vitality and health emerges. With a dynamic range from 14 to 103, underscored by a standard deviation of 13.63, our dataset mirrors the rich tapestry of human diversity. Each entry, meticulously recorded, encapsulates a story waiting to be told.
#
# Demographic Dynamics:
#
# Within the spectrum of age, a symphony of life unfolds. Between the youthful vigor of 20 and 40 lies a cohort of 55 individuals, a testament to the vibrancy of our young populace. Yet, it's the golden years, between 50 and 60, that steal the spotlight with over 200 souls navigating the passage of time. As the years advance, a gradual decline in numbers hints at the ebb and flow of demographics. Notably, the mantle of youth seems to be donned by a significant majority, painting a picture of demographic vigor favoring the young.
#
# Health Insights:
#
# Amidst the intricate web of age and gender, health considerations emerge. Blood sugar, a barometer of well-being, commands attention. Individuals aged 90 to 100 are advised vigilance, as the specter of fluctuating blood sugar looms. A nuanced interplay between age and glucose levels unveils itself, with a gentle descent from 20 to 80, punctuated by warnings for the young and elderly alike. Within this narrative, the silhouette of gender becomes pronounced, with females dominating between 50 to 70, while males assert their presence between 47 to 65.
#
# Healthscape:
#
# The canvas of health, painted by the heatmap, reveals intriguing patterns. A subtle dance between age and blood sugar unfolds, with a gentle negative correlation whispering tales of physiological nuances. While variability punctuates the landscape, a prevailing trend emerges—blood sugar levels tend to gracefully wane with advancing age, albeit with nuances across demographics.
#
# In the symphony of data, each note resonates with the promise of insight. As we navigate its depths, we uncover not just numbers, but narratives—stories of life, health, and t --> human spirit.

# %% [markdown]
# Made By Sanjaya Kumar Giri
